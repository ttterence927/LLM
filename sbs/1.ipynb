# %%
import pandas as pd
import numpy as np
data = pd.read_pickle('sbs_class.data')

# %%
data
# Out:
#                      open_sbs  high_sbs   low_sbs  close_sbs  causers_sbs  \
# 2016-08-10 18:00:00 -0.592831 -0.674660 -0.466903  -0.543219    -0.634326
# 2016-08-10 19:00:00 -0.547418 -0.573284 -0.421459  -0.459790    -0.604030
# 2016-08-10 20:00:00 -0.469507 -0.441871 -0.357299  -0.316385    -0.546968
# 2016-08-10 21:00:00 -0.317347 -0.185320 -0.197103  -0.062374    -0.458905
# 2016-08-10 22:00:00 -0.066437 -0.038809  0.055879   0.080940    -0.289051
# ...                       ...       ...       ...        ...          ...
# 2023-09-24 19:00:00 -1.130645 -0.778738 -1.003180  -0.645179    -0.866571
# 2023-09-24 20:00:00 -0.649178 -0.440635 -0.523710  -0.321560    -0.711724
# 2023-09-24 21:00:00 -0.328036 -0.300497 -0.259629  -0.185949    -0.567489
# 2023-09-24 22:00:00 -0.195814 -0.127825 -0.092551  -0.043016    -0.493971
# 2023-09-24 23:00:00 -0.058830 -0.179311 -0.114703  -0.236736    -0.474483
#
#                      helpers_sbs  green_max_sbs  orange_max_sbs  red_max_sbs  \
# ...
